# %% [markdown]
# <a href="https://colab.research.google.com/github/riza-cloud/RouteLink_SDG9_Logistic_Delivery_and_Tracking_System/blob/main/routes_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile routes.py
routes = {
    "Warehouse": ["Area A", "Area B"],
    "Area A": ["Area C", "Area D"],
    "Area B": ["Area E", "Area F"],
    "Area C": [],
    "Area D": [],
    "Area E": [],
    "Area F": []
}
# Out:
# Overwriting routes.py

# %%
import networkx as nx
from routes import routes
import matplotlib.pyplot as plt

G= nx.DiGraph()

for source, destinations in routes.items():
  for dest in destinations:
    G.add_edge(source,dest)

nx.draw(G,with_labels=True,
        node_size=2300, font_size=10)
plt.show()

# %%
import importlib
import routes
importlib.reload(routes)
from routes import routes
